# %%
# series kind of vertical one Dimetional array 
import numpy as np
import pandas as pd

# %%
labels=['a','b','c','d']
data=[10,20,30,40]
arr=np.array([1,2,3,4])
d={1:10,2:20,3:30,4:40}

# %%
# Craeting a series using pandas 

# pd.Series(data) labels are the indes by default  
# pd.Series(data,labels)  
# pd.Series(arr,labels) # But we can not use 2d arrray to make series
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
pd.Series(d)  # now the Series is build using label -> key and value is dictionary value
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64
